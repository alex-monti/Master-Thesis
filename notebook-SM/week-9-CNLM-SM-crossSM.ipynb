# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from functions_NLM import estimate_nested_logit, simulate_choice
from functions_geom_DIB import geom_DIB_on_alternatives

# %%
# Load data
data = pd.read_csv('../data/swissmetro.dat', sep='\t')

# %%
data_used = data[['ID', 'TRAIN_TT', 'SM_TT', 'CAR_TT', 'TRAIN_CO', 'SM_CO', 'CAR_CO',
                   'TRAIN_AV', 'SM_AV', 'CAR_AV', 'GA', 'CHOICE']]

# %%
# DEFINE MODEL STRUCTURE AND LIKELIHOOD FUNCTION
def log_likelihood_SM_CNLM(beta, data):
    alpha_SM_WITH_CAR = np.exp(beta[6]) / (1 + np.exp(beta[6]))
    alpha_SM_WITH_TRAIN = 1 - alpha_SM_WITH_CAR

    # define utility functions
    data['U_TRAIN'] = beta[2] * data['TRAIN_TT'] + beta[3] * (data['GA'] == 0) * data['TRAIN_CO']
    data['U_SM'] = beta[1] + beta[2] * data['SM_TT'] + beta[3] * (data['GA'] == 0) * data['SM_CO']
    data['U_CAR'] = beta[0] + beta[2] * data['CAR_TT'] + beta[3] * data['CAR_CO']

    # combined utility terms inside nests
    data['U_CAR_SM'] = (alpha_SM_WITH_CAR * data['SM_AV'] * np.exp(data['U_SM'])) ** (1 / beta[4]) + \
                          (1 * data['CAR_AV'] * np.exp(data['U_CAR'])) ** (1 / beta[4])
    data['U_SM_TRAIN'] = (alpha_SM_WITH_TRAIN * data['SM_AV'] * np.exp(data['U_SM'])) ** (1 / beta[5]) + \
                         (1 * data['TRAIN_AV'] * np.exp(data['U_TRAIN'])) ** (1 / beta[5])

    # Nest probabilities
    data['P_nest_CAR_SM'] = (data['U_CAR_SM'] ** beta[4]) / \
                                (data['U_CAR_SM'] ** beta[4] + data['U_SM_TRAIN'] ** beta[5])
    data['P_nest_SM_TRAIN'] = 1 - data['P_nest_CAR_SM']

    # Within nest probabilities for any nests with > 1 alt
    data['P_SM_in_CAR_SM'] = ((alpha_SM_WITH_CAR * data['SM_AV'] * np.exp(data['U_SM'])) ** (1 / beta[4])) / \
                                data['U_CAR_SM']
    data['P_CAR_in_CAR_SM'] = 1 - data['P_SM_in_CAR_SM']
    data['P_SM_in_SM_TRAIN'] = ((alpha_SM_WITH_TRAIN * data['SM_AV'] * np.exp(data['U_SM'])) ** (1 / beta[5])) / \
                                    data['U_SM_TRAIN']
    data['P_TRAIN_in_SM_TRAIN'] = 1 - data['P_SM_in_SM_TRAIN']

    # Full probabilities
    data['P_TRAIN_1'] = data['P_nest_SM_TRAIN'] * data['P_TRAIN_in_SM_TRAIN']
    data['P_SM_2'] = data['P_nest_SM_TRAIN'] * data['P_SM_in_SM_TRAIN'] + \
                        data['P_nest_CAR_SM'] * data['P_SM_in_CAR_SM']
    data['P_CAR_3'] = data['P_nest_CAR_SM'] * data['P_CAR_in_CAR_SM']

    # calculate probability for chosen alternative for each row in the data table
    data['P'] = ((data['CHOICE'] == 1) * data['P_TRAIN_1'] +
                 (data['CHOICE'] == 2) * data['P_SM_2'] +
                 (data['CHOICE'] == 3) * data['P_CAR_3'])

    # take product across choices for the same person (likelihood)
    # then take the log for log-likelihood
    LL = data.groupby('ID')['P'].prod().apply(np.log).sum()

    return -LL  # We minimize negative log-likelihood

# %%
# DEFINE MODEL PARAMETERS
beta = np.array([0, 0, 0, 0, 1, 1, 0])
beta_names = ["ASC_CAR", "ASC_SM", "BETA_TT", "BETA_TC", "lambda_CAR_TRAIN", "lambda_SM_TRAIN", "base_alpha_TRAIN_WITH_CAR"]


# Estimate parameters
result, se, t_stat, p_value, aic, bic  = estimate_nested_logit(data_used, beta, beta_names, log_likelihood_SM_CNLM)
# Out:
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_15796/2295807302.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_TRAIN'] = beta[2] * data['TRAIN_TT'] + beta[3] * (data['GA'] == 0) * data['TRAIN_CO']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_15796/2295807302.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_SM'] = beta[1] + beta[2] * data['SM_TT'] + beta[3] * (data['GA'] == 0) * data['SM_CO']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_15796/2295807302.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_CAR'] = beta[0] + beta[2] * data['CAR_TT'] + beta[3] * data['CAR_CO']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_15796/2295807302.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_CAR_SM'] = (alpha_SM_WITH_CAR * data['SM_AV'] * np.exp(data['U_SM'])) ** (1 / beta[4]) + \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_15796/2295807302.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_SM_TRAIN'] = (alpha_SM_WITH_TRAIN * data['SM_AV'] * np.exp(data['U_SM'])) ** (1 / beta[5]) + \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_15796/2295807302.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_nest_CAR_SM'] = (data['U_CAR_SM'] ** beta[4]) / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_15796/2295807302.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_nest_SM_TRAIN'] = 1 - data['P_nest_CAR_SM']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_15796/2295807302.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_SM_in_CAR_SM'] = ((alpha_SM_WITH_CAR * data['SM_AV'] * np.exp(data['U_SM'])) ** (1 / beta[4])) / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_15796/2295807302.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_CAR_in_CAR_SM'] = 1 - data['P_SM_in_CAR_SM']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_15796/2295807302.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_SM_in_SM_TRAIN'] = ((alpha_SM_WITH_TRAIN * data['SM_AV'] * np.exp(data['U_SM'])) ** (1 / beta[5])) / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_15796/2295807302.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_TRAIN_in_SM_TRAIN'] = 1 - data['P_SM_in_SM_TRAIN']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_15796/2295807302.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_TRAIN_1'] = data['P_nest_SM_TRAIN'] * data['P_TRAIN_in_SM_TRAIN']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_15796/2295807302.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_SM_2'] = data['P_nest_SM_TRAIN'] * data['P_SM_in_SM_TRAIN'] + \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_15796/2295807302.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_CAR_3'] = data['P_nest_CAR_SM'] * data['P_CAR_in_CAR_SM']
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:590: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:590: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:590: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:590: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:590: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:590: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:590: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# Optimization Results:
#                    Parameter  Estimate  Robust Asymptotic SE  t-statistic  \
# 0                    ASC_CAR -2.148966              0.219706    -9.781088
# 1                     ASC_SM  0.206893              0.116850     1.770587
# 2                    BETA_TT -0.029486              0.001467   -20.092575
# 3                    BETA_TC -0.021405              0.000984   -21.752910
# 4           lambda_CAR_TRAIN  8.781123              0.025130   349.425149
# 5            lambda_SM_TRAIN  1.814824              0.126595    14.335714
# 6  base_alpha_TRAIN_WITH_CAR -7.769435              0.506294   -15.345705
#
#     p-value
# 0  0.000000
# 1  0.076658
# 2  0.000000
# 3  0.000000
# 4  0.000000
# 5  0.000000
# 6  0.000000
# AIC: 16923.274882700705
# BIC: 16974.227414844798
# Log-likelihood: -8454.637441350353

# %%
df_input = data[['TRAIN_TT', 'SM_TT', 'CAR_TT', 'TRAIN_CO', 'SM_CO', 'CAR_CO',
                  'TRAIN_AV', 'SM_AV', 'CAR_AV', 'GA']]
# Calculate frequencies and probabilities
vector_counts = df_input.value_counts().reset_index(name='Frequency')
vector_counts['Probability'] = vector_counts['Frequency'] / len(df_input)

# Creating a tuple of attributes to facilitate mapping
vector_counts['tuple'] = vector_counts[['TRAIN_TT', 'SM_TT', 'CAR_TT', 'TRAIN_CO', 'SM_CO', 'CAR_CO',
                                        'TRAIN_AV', 'SM_AV', 'CAR_AV', 'GA']].apply(tuple, axis=1)
probability_map = vector_counts.set_index('tuple')['Probability'].to_dict()

# Assign the probability to each row based on its tuple of attributes
df_input['Probability'] = df_input.apply(lambda row: probability_map[tuple(row)], axis=1)
# Out:
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_15796/1669296022.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_input['Probability'] = df_input.apply(lambda row: probability_map[tuple(row)], axis=1)

# %%
# Computation of p(x,y)
p_x = df_input['Probability'].values

p_y_given_x = data_used[['P_TRAIN_1', 'P_SM_2', 'P_CAR_3']].values
p_xy = p_x[:, np.newaxis] * p_y_given_x

# Normalize p_xy 
p_xy /= p_xy.sum()

# Define epsilon value
epsilon = 1e-20

# Add epsilon to elements equal to 0
p_xy[p_xy == 0] += epsilon

# %%
def simulate_choice_SM(row):
    """
    Function to simulate a choice based on cumulative probabilities.

    Parameters:
    - row: pandas Series or DataFrame row containing probabilities for each choice

    Returns:
    - The simulated choice (an integer between 1 and the number of choices)
    """
    # Generate a random number between 0 and 1
    random_number = np.random.rand()
    
    # Calculate cumulative probabilities
    probabilities = row[['P_TRAIN_1', 'P_SM_2', 'P_CAR_3']]
    cumulative_probs = probabilities.cumsum()
    
    # Determine simulated choice based on random number
    for i, cumulative_prob in enumerate(cumulative_probs):
        if random_number <= cumulative_prob:
            return i+1

# %%
np.random.seed(123)
data_used['simulated_choice'] = data_used.apply(simulate_choice_SM, axis=1)

# %%
betas = np.linspace(0, 50, 51)
# Initialize an empty list to store the number of clusters
num_clusters_list = []

# Iterate over each beta value
for beta in betas:
    # Run iterative_algorithm to obtain q_t_given_x
    q_t_given_x, _, _ = geom_DIB_on_alternatives(p_xy, max_iter=5000, beta=beta, threshold=1e-3)
    
    # Calculate the number of clusters
    column_sum = np.sum(q_t_given_x, axis=0)
    num_clusters = np.count_nonzero(column_sum)
    
    # Append the number of clusters to the list
    num_clusters_list.append(num_clusters)

# Plot the number of clusters against beta values
plt.plot(betas, num_clusters_list)
plt.xlabel('Beta')
plt.ylabel('Number of Clusters')
plt.title('Number of Clusters vs. Beta')
plt.grid(True)
plt.show()
# Out:
# Iteration: 1 out of 5000
# Objective function value: 1.0986119248215014
# H(T) =  1.0986119248215014
# I(T;Y) =  2.380731977691397e-05
# Iteration: 2 out of 5000
# Objective function value: 0.7962520783544135
# H(T) =  0.7962520783544135
# I(T;Y) =  9.52332133330458e-06
# Iteration: 3 out of 5000
# Objective function value: 0.6001331339118811
# H(T) =  0.6001331339118811
# I(T;Y) =  6.073983753296375e-06
# Iteration: 4 out of 5000
# Objective function value: 0.4850734045945699
# H(T) =  0.4850734045945699
# I(T;Y) =  4.4589827761232215e-06
# Iteration: 5 out of 5000
# Objective function value: 0.40944437118304994
# H(T) =  0.40944437118304994
# I(T;Y) =  3.522437366898501e-06
# Iteration: 6 out of 5000
# Objective function value: 0.3557024077508029
# H(T) =  0.3557024077508029
# I(T;Y) =  2.911036464325889e-06
# Iteration: 7 out of 5000
# Objective function value: 0.31538826551743104
# H(T) =  0.31538826551743104
# I(T;Y) =  2.4805024825269584e-06
# Iteration: 8 out of 5000
# Objective function value: 0.2839298985028169
# H(T) =  0.2839298985028169
# I(T;Y) =  2.160919814864215e-06
# Iteration: 9 out of 5000
# Objective function value: 0.25863574268194445
# H(T) =  0.25863574268194445
# I(T;Y) =  1.9142948424200057e-06
# Iteration: 10 out of 5000
# Objective function value: 0.23781469323433357
# H(T) =  0.23781469323433357
# I(T;Y) =  1.7182038312135717e-06
# Iteration: 11 out of 5000
# Objective function value: 0.22034867702877203
# H(T) =  0.22034867702877203
# I(T;Y) =  1.5585583978960926e-06
# Iteration: 12 out of 5000
# Objective function value: 0.20546761342208303
# H(T) =  0.20546761342208303
# I(T;Y) =  1.426061806641954e-06
# Iteration: 13 out of 5000
# Objective function value: 0.1926230142482518
# H(T) =  0.1926230142482518
# I(T;Y) =  1.3143314818719887e-06
# Iteration: 14 out of 5000
# Objective function value: 0.18141313267255385
# H(T) =  0.18141313267255385
# I(T;Y) =  1.2188401461443732e-06
# Iteration: 15 out of 5000
# Objective function value: 0.17153664537400623
# H(T) =  0.17153664537400623
# I(T;Y) =  1.1362873599818357e-06
# Iteration: 16 out of 5000
# Objective function value: 0.16276290678570643
# H(T) =  0.16276290678570643
# I(T;Y) =  1.0642103196456532e-06
# Iteration: 17 out of 5000
# Objective function value: 0.15491222940893923
# H(T) =  0.15491222940893923
# I(T;Y) =  1.0007339759088296e-06
# Iteration: 18 out of 5000
# Objective function value: 0.1478424464472899
# H(T) =  0.1478424464472899
# I(T;Y) =  9.444055704133092e-07
# Iteration: 19 out of 5000
# Objective function value: 0.14143953270689175
# H(T) =  0.14143953270689175
# I(T;Y) =  8.94082087699033e-07
# Iteration: 20 out of 5000
# Objective function value: 0.13561091802593805
# H(T) =  0.13561091802593805
# I(T;Y) =  8.488518830063185e-07
# Iteration: 21 out of 5000
# Objective function value: 0.1302806297859627
# H(T) =  0.1302806297859627
# I(T;Y) =  8.079789617365662e-07
# Iteration: 22 out of 5000
# Objective function value: 0.1253857043435103
# H(T) =  0.1253857043435103
# I(T;Y) =  7.708626141855746e-07
# Iteration: 23 out of 5000
# Objective function value: 0.12087349551038325
# H(T) =  0.12087349551038325
# I(T;Y) =  7.370077033108657e-07
# Iteration: 24 out of 5000
# Objective function value: 0.11669962805013467
# H(T) =  0.11669962805013467
# I(T;Y) =  7.06002443617848e-07
# Iteration: 25 out of 5000
# Objective function value: 0.11282642215792427
# H(T) =  0.11282642215792427
# I(T;Y) =  6.775015732873868e-07
# Iteration: 26 out of 5000
# Objective function value: 0.10922166669619493
# H(T) =  0.10922166669619493
# I(T;Y) =  6.512134398395375e-07
# Iteration: 27 out of 5000
# Objective function value: 0.10585765400557433
# H(T) =  0.10585765400557433
# I(T;Y) =  6.268899861439081e-07
# Iteration: 28 out of 5000
# Objective function value: 0.10271041322187201
# H(T) =  0.10271041322187201
# I(T;Y) =  6.0431889559176e-07
# Iteration: 29 out of 5000
# Objective function value: 0.0997590958757446
# H(T) =  0.0997590958757446
# I(T;Y) =  5.833173823965865e-07
# Iteration: 30 out of 5000
# Objective function value: 0.09698547948902228
# H(T) =  0.09698547948902228
# I(T;Y) =  5.63727226010613e-07
# Iteration: 31 out of 5000
# Objective function value: 0.09437356345243621
# H(T) =  0.09437356345243621
# I(T;Y) =  5.454107814273357e-07
# Iteration: 32 out of 5000
# Objective function value: 0.09190923769810108
# H(T) =  0.09190923769810108
# I(T;Y) =  5.282477386625573e-07
# Iteration: 33 out of 5000
# Objective function value: 0.08958000925789561
# H(T) =  0.08958000925789561
# I(T;Y) =  5.121324773149638e-07
# Iteration: 34 out of 5000
# Objective function value: 0.08737477519885883
# H(T) =  0.08737477519885883
# I(T;Y) =  4.969718907510412e-07
# Iteration: 35 out of 5000
# Objective function value: 0.08528363297677162
# H(T) =  0.08528363297677162
# I(T;Y) =  4.826835864335521e-07
# Iteration: 36 out of 5000
# Objective function value: 0.08329772117928713
# H(T) =  0.08329772117928713
# I(T;Y) =  4.6919438800863134e-07
# Iteration: 37 out of 5000
# Objective function value: 0.08140908510362167
# H(T) =  0.08140908510362167
# I(T;Y) =  4.564390811978569e-07
# Iteration: 38 out of 5000
# Objective function value: 0.07961056274798156
# H(T) =  0.07961056274798156
# I(T;Y) =  4.4435936019660005e-07
# Iteration: 39 out of 5000
# Objective function value: 0.07789568767551612
# H(T) =  0.07789568767551612
# I(T;Y) =  4.3290293594289153e-07
# Iteration: 40 out of 5000
# Objective function value: 0.07625860589663669
# H(T) =  0.07625860589663669
# I(T;Y) =  4.2202278027758666e-07
# Iteration: 41 out of 5000
# Objective function value: 0.07469400445586707
# H(T) =  0.07469400445586707
# I(T;Y) =  4.116764791284311e-07
# Iteration: 42 out of 5000
# Objective function value: 0.07319704983705459
# H(T) =  0.07319704983705459
# I(T;Y) =  4.0182568161739596e-07
# Iteration: 43 out of 5000
# Objective function value: 0.07176333464131071
# H(T) =  0.07176333464131071
# I(T;Y) =  3.9243562488522343e-07
# Iteration: 44 out of 5000
# Objective function value: 0.07038883126480873
# H(T) =  0.07038883126480873
# I(T;Y) =  3.834747221986845e-07
# Iteration: 45 out of 5000
# Objective function value: 0.06906985152322065
# H(T) =  0.06906985152322065
# I(T;Y) =  3.749142107878356e-07
# Iteration: 46 out of 5000
# Objective function value: 0.06780301134738695
# H(T) =  0.06780301134738695
# I(T;Y) =  3.667278418717501e-07
# Iteration: 47 out of 5000
# Objective function value: 0.06658519981948477
# H(T) =  0.06658519981948477
# I(T;Y) =  3.5889161154045723e-07
# Iteration: 48 out of 5000
# Objective function value: 0.06541355193721521
# H(T) =  0.06541355193721521
# I(T;Y) =  3.5138352671992834e-07
# Iteration: 49 out of 5000
# Objective function value: 0.06428542459063195
# H(T) =  0.06428542459063195
# I(T;Y) =  3.441833975603714e-07
# Iteration: 50 out of 5000
# Objective function value: 0.06319837531632498
# H(T) =  0.06319837531632498
# I(T;Y) =  3.372726586903241e-07
# Iteration: 51 out of 5000
# Objective function value: 0.06215014345997963
# H(T) =  0.06215014345997963
# I(T;Y) =  3.3063420690204737e-07
# Iteration: 52 out of 5000
# Objective function value: 0.06113863343348498
# H(T) =  0.06113863343348498
# I(T;Y) =  3.2425226037524624e-07
# Iteration: 1 out of 5000
# Objective function value: 1.0985881175017245
# H(T) =  1.0986119248215014
# I(T;Y) =  2.380731977691397e-05
# Iteration: 2 out of 5000
# Objective function value: 1.0223239770041925
# H(T) =  1.0502053862281024
# I(T;Y) =  0.027881409223909914
# Iteration: 3 out of 5000
# Objective function value: 0.9444286370712831
# H(T) =  0.9512665632856951
# I(T;Y) =  0.006837926214412038
# Iteration: 4 out of 5000
# Objective function value: 0.6832653082058947
# H(T) =  0.687051755977436
# I(T;Y) =  0.003786447771541246
# Iteration: 5 out of 5000
# Objective function value: 0.5324037713780516
# H(T) =  0.5350170371685741
# I(T;Y) =  0.0026132657905224566
# Iteration: 6 out of 5000
# Objective function value: 0.43902228880330896
# H(T) =  0.4410167186462276
# I(T;Y) =  0.0019944298429186436
# Iteration: 7 out of 5000
# Objective function value: 0.3754344265657462
# H(T) =  0.37704681735338974
# I(T;Y) =  0.001612390787643525
# Iteration: 8 out of 5000
# Objective function value: 0.329156094093274
# H(T) =  0.3305092173832364
# I(T;Y) =  0.001353123289962399
# Iteration: 9 out of 5000
# Objective function value: 0.29384082365119757
# H(T) =  0.2950064826877894
# I(T;Y) =  0.0011656590365918262
# Iteration: 10 out of 5000
# Objective function value: 0.2659259891813398
# H(T) =  0.26694979426726795
# I(T;Y) =  0.0010238050859281422
# Iteration: 11 out of 5000
# Objective function value: 0.2432544371468363
# H(T) =  0.24416716163268343
# I(T;Y) =  0.0009127244858471162
# Iteration: 12 out of 5000
# Objective function value: 0.22444115425407593
# H(T) =  0.22526453917688513
# I(T;Y) =  0.0008233849228092005
# Iteration: 13 out of 5000
# Objective function value: 0.20855455849476778
# H(T) =  0.2093045318567005
# I(T;Y) =  0.0007499733619327209
# Iteration: 14 out of 5000
# Objective function value: 0.19494397707359662
# H(T) =  0.19563255637443883
# I(T;Y) =  0.000688579300842207
# Iteration: 15 out of 5000
# Objective function value: 0.18314055656002037
# H(T) =  0.18377703193361272
# I(T;Y) =  0.000636475373592349
# Iteration: 16 out of 5000
# Objective function value: 0.17279749699808827
# H(T) =  0.17338919839944905
# I(T;Y) =  0.000591701401360778
# Iteration: 17 out of 5000
# Objective function value: 0.16365249581686137
# H(T) =  0.164205308198336
# I(T;Y) =  0.0005528123814746433
# Iteration: 18 out of 5000
# Objective function value: 0.1555033115238162
# H(T) =  0.1560220312083606
# I(T;Y) =  0.000518719684544422
# Iteration: 19 out of 5000
# Objective function value: 0.14819138039664295
# H(T) =  0.14867996797477515
# I(T;Y) =  0.0004885875781321936
# Iteration: 20 out of 5000
# Objective function value: 0.14159054255209266
# H(T) =  0.14205230637616603
# I(T;Y) =  0.000461763824073369
# Iteration: 21 out of 5000
# Objective function value: 0.13559910474445924
# H(T) =  0.13603683668547573
# I(T;Y) =  0.0004377319410164837
# Iteration: 22 out of 5000
# Objective function value: 0.1301341383344327
# H(T) =  0.13055021596680008
# I(T;Y) =  0.00041607763236739537
# Iteration: 23 out of 5000
# Objective function value: 0.125127308651178
# H(T) =  0.12552377335817583
# I(T;Y) =  0.0003964647069978344
# Iteration: 24 out of 5000
# Objective function value: 0.12052177488869403
# H(T) =  0.12090039239093958
# I(T;Y) =  0.00037861750224554847
# Iteration: 25 out of 5000
# Objective function value: 0.11626985201774213
# H(T) =  0.11663215986673973
# I(T;Y) =  0.0003623078489976006
# Iteration: 26 out of 5000
# Objective function value: 0.11233122403516599
# H(T) =  0.1126785693012618
# I(T;Y) =  0.00034734526609581096
# Iteration: 27 out of 5000
# Objective function value: 0.10867156207578677
# H(T) =  0.10900513156350167
# I(T;Y) =  0.000333569487714902
# Iteration: 28 out of 5000
# Objective function value: 0.10526144387164962
# H(T) =  0.10558228857249966
# I(T;Y) =  0.00032084470085003147
# Iteration: 29 out of 5000
# Objective function value: 0.1020755003031405
# H(T) =  0.10238455535625757
# I(T;Y) =  0.0003090550531170688
# Iteration: 30 out of 5000
# Objective function value: 0.0990917350415276
# H(T) =  0.0993898361572704
# I(T;Y) =  0.0002981011157427993
# Iteration: 31 out of 5000
# Objective function value: 0.0962909775145721
# H(T) =  0.09657887458747753
# I(T;Y) =  0.00028789707290544087
# Iteration: 32 out of 5000
# Objective function value: 0.09365643956531548
# H(T) =  0.09393480803448089
# I(T;Y) =  0.00027836846916540203
# Iteration: 33 out of 5000
# Objective function value: 0.09117335348875939
# H(T) =  0.0914428038786071
# I(T;Y) =  0.0002694503898477141
# Iteration: 34 out of 5000
# Objective function value: 0.08882867447095574
# H(T) =  0.0890897604512578
# I(T;Y) =  0.000261085980302056
# Iteration: 35 out of 5000
# Objective function value: 0.08661083439610341
# H(T) =  0.08686405962873912
# I(T;Y) =  0.00025322523263571206
# Iteration: 36 out of 5000
# Objective function value: 0.08450953692585648
# H(T) =  0.0847553609110475
# I(T;Y) =  0.0002458239851910182
# Iteration: 37 out of 5000
# Objective function value: 0.08251558596716388
# H(T) =  0.08275442905965721
# I(T;Y) =  0.0002388430924933349
# Iteration: 38 out of 5000
# Objective function value: 0.08062074132517726
# H(T) =  0.08085298905788539
# I(T;Y) =  0.00023224773270813515
# Iteration: 39 out of 5000
# Objective function value: 0.07881759662467791
# H(T) =  0.07904360345143358
# I(T;Y) =  0.00022600682675566475
# Iteration: 40 out of 5000
# Objective function value: 0.07709947557700622
# H(T) =  0.07731956812562377
# I(T;Y) =  0.00022009254861754535
# Iteration: 41 out of 5000
# Objective function value: 0.0754603434421886
# H(T) =  0.07567482335276471
# I(T;Y) =  0.00021447991057610416
# Iteration: 42 out of 5000
# Objective function value: 0.07389473114120951
# H(T) =  0.07410387755153217
# I(T;Y) =  0.00020914641032265813
# Iteration: 43 out of 5000
# Objective function value: 0.07239766995055559
# H(T) =  0.07260174168000184
# I(T;Y) =  0.00020407172944625351
# Iteration: 44 out of 5000
# Objective function value: 0.07096463508979033
# H(T) =  0.07116387256456179
# I(T;Y) =  0.00019923747477146314
# Iteration: 45 out of 5000
# Objective function value: 0.06959149681512353
# H(T) =  0.06978612377073343
# I(T;Y) =  0.00019462695560990007
# Iteration: 46 out of 5000
# Objective function value: 0.06827447787450341
# H(T) =  0.06846470286573852
# I(T;Y) =  0.0001902249912351106
# Iteration: 47 out of 5000
# Objective function value: 0.06701011637552984
# H(T) =  0.06719613411944109
# I(T;Y) =  0.0001860177439112487
# Iteration: 48 out of 5000
# Objective function value: 0.06579523327628363
# H(T) =  0.0659772258498736
# I(T;Y) =  0.000181992573589973
# Iteration: 49 out of 5000
# Objective function value: 0.06462690383858956
# H(T) =  0.0648050417496739
# I(T;Y) =  0.00017813791108434174
# Iteration: 50 out of 5000
# Objective function value: 0.06350243248926454
# H(T) =  0.06367687563627686
# I(T;Y) =  0.00017444314701231534
# Iteration: 51 out of 5000
# Objective function value: 0.0624193306220541
# H(T) =  0.06259022915634041
# I(T;Y) =  0.0001708985342863123
# Iteration: 52 out of 5000
# Objective function value: 0.061375296945029544
# H(T) =  0.06154279204728743
# I(T;Y) =  0.00016749510225788633
# Iteration: 53 out of 5000
# Objective function value: 0.060368200037950834
# H(T) =  0.06053242461885809
# I(T;Y) =  0.00016422458090725733
# Iteration: 1 out of 5000
# Objective function value: 1.0985643101819476
# H(T) =  1.0986119248215014
# I(T;Y) =  2.380731977691397e-05
# Iteration: 2 out of 5000
# Objective function value: 0.9343829667865267
# H(T) =  0.9793574002487113
# I(T;Y) =  0.02248721673109233
# Iteration: 3 out of 5000
# Objective function value: 0.3821461152553017
# H(T) =  0.405043722098889
# I(T;Y) =  0.011448803421793663
# Iteration: 4 out of 5000
# Objective function value: 0.7151403298897748
# H(T) =  0.7215753989481412
# I(T;Y) =  0.0032175345291831636
# Iteration: 5 out of 5000
# Objective function value: 0.5669925449232033
# H(T) =  0.5703037493756223
# I(T;Y) =  0.0016556022262095293
# Iteration: 6 out of 5000
# Objective function value: 0.45384947414231547
# H(T) =  0.4560785692707937
# I(T;Y) =  0.0011145475642391212
# Iteration: 7 out of 5000
# Objective function value: 0.37958759822835364
# H(T) =  0.3812676480692827
# I(T;Y) =  0.0008400249204645327
# Iteration: 8 out of 5000
# Objective function value: 0.3275955905136348
# H(T) =  0.32894361107330533
# I(T;Y) =  0.0006740102798352687
# Iteration: 9 out of 5000
# Objective function value: 0.2891110771417774
# H(T) =  0.29023664998968435
# I(T;Y) =  0.0005627864239534652
# Iteration: 10 out of 5000
# Objective function value: 0.2593980873587806
# H(T) =  0.26036422933780873
# I(T;Y) =  0.00048307098951405614
# Iteration: 11 out of 5000
# Objective function value: 0.23570613737413934
# H(T) =  0.23655240977546851
# I(T;Y) =  0.0004231362006645867
# Iteration: 12 out of 5000
# Objective function value: 0.2163325337568715
# H(T) =  0.21708539802783328
# I(T;Y) =  0.0003764321354808864
# Iteration: 13 out of 5000
# Objective function value: 0.20016660957761376
# H(T) =  0.20084463603383648
# I(T;Y) =  0.00033901322811136225
# Iteration: 14 out of 5000
# Objective function value: 0.18645227787150473
# H(T) =  0.18706899964627352
# I(T;Y) =  0.0003083608873843957
# Iteration: 15 out of 5000
# Objective function value: 0.174656387777247
# H(T) =  0.17522197153640395
# I(T;Y) =  0.0002827918795784701
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 8
#       5 # Iterate over each beta value
#       6 for beta in betas:
#       7     # Run iterative_algorithm to obtain q_t_given_x
# ----> 8     q_t_given_x, _, _ = geom_DIB_on_alternatives(p_xy, max_iter=5000, beta=beta, threshold=1e-3)
#      10     # Calculate the number of clusters
#      11     column_sum = np.sum(q_t_given_x, axis=0)
#
# File ~/Documents/GitHub/Semester_project_information_cluser/notebook-SM/functions_geom_DIB.py:357, in geom_DIB_on_alternatives(p_xy, max_iter, beta, threshold)
#     355 for i in range(num_data_points):
#     356     for j in range(num_clusters):
# --> 357         d_xt[i, j] = kl_divergence(p_y_given_x[i], q_y_given_t[j])
#     359 l_beta_xt = np.log(q_t) - beta * d_xt
#     360 f_x = np.argmax(l_beta_xt, axis=1)
#
# File ~/Documents/GitHub/Semester_project_information_cluser/notebook-SM/functions_IB.py:21, in kl_divergence(p, q)
#      18 q = np.asarray(q, dtype=float)
#      20 # Ensure that distributions sum up to 1
# ---> 21 p = p / np.sum(p)
#      22 q = q / np.sum(q)
#      24 # Ignore division by zero warning when q[i] is 0
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2313, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2310         return out
#    2311     return res
# -> 2313 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2314                       initial=initial, where=where)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/numpy/core/fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %%
q_t_given_x, q_t, q_y_given_t = geom_DIB_on_alternatives(p_xy, beta=100, max_iter=5000, threshold=1e-4)
# Out:
# Iteration: 1 out of 5000
# Objective function value: 1.09623119284381
# H(T) =  1.0986119248215014
# I(T;Y) =  2.380731977691397e-05
# Iteration: 2 out of 5000
# Objective function value: -7.3645595453648705
# H(T) =  0.9331889327234133
# I(T;Y) =  0.08297748478088285
# Iteration: 3 out of 5000
# Objective function value: -7.92121855932959
# H(T) =  1.0065415250938958
# I(T;Y) =  0.08927760084423486
# Iteration: 4 out of 5000
# Objective function value: -8.623983125605077
# H(T) =  1.0482003437375436
# I(T;Y) =  0.09672183469342621
# Iteration: 5 out of 5000
# Objective function value: -9.258150996710539
# H(T) =  1.0646666474679445
# I(T;Y) =  0.10322817644178484
# Iteration: 6 out of 5000
# Objective function value: -9.454269811431354
# H(T) =  1.0616909833067347
# I(T;Y) =  0.10515960794738088
# Iteration: 7 out of 5000
# Objective function value: -9.505284526983806
# H(T) =  1.0556821806143564
# I(T;Y) =  0.10560966707598163
# Iteration: 8 out of 5000
# Objective function value: -9.522708033753334
# H(T) =  1.049971387800376
# I(T;Y) =  0.1057267942155371
# Iteration: 9 out of 5000
# Objective function value: -9.528944431965638
# H(T) =  1.0464110427081499
# I(T;Y) =  0.10575355474673787
# Iteration: 10 out of 5000
# Objective function value: -9.530850009275948
# H(T) =  1.0441923589572182
# I(T;Y) =  0.10575042368233167
# Iteration: 11 out of 5000
# Objective function value: -9.53135724162177
# H(T) =  1.0433165683359207
# I(T;Y) =  0.10574673809957691
# Iteration: 12 out of 5000
# Objective function value: -9.531533722148298
# H(T) =  1.0429929311821746
# I(T;Y) =  0.10574526653330474
# Iteration: 13 out of 5000
# Objective function value: -9.531645235216292
# H(T) =  1.0426371931475984
# I(T;Y) =  0.1057428242836389

# %%
import re

# Define a function to extract the number from the column name
def extract_number(column_name):
    match = re.search(r'\d+', column_name)  # Search for one or more digits in the column name
    if match:
        return int(match.group())  # Return the first occurrence of digits as an integer
    else:
        return None  # Return None if no digits are found

# %%
# Calculate the number of clusters
column_sum = np.sum(q_t_given_x, axis=0)
num_clusters = np.count_nonzero(column_sum)
print('Number of clusters :', num_clusters)

# Count the number of observations in each cluster
data_used['cluster'] = np.argmax(q_t_given_x, axis=1)
print('\n', data_used['cluster'].value_counts())

# number of each alternative 1, 2, 3, 4, 5 in each cluster 
cluster_counts = data_used.groupby(['cluster', 'CHOICE']).size().unstack(fill_value=0)
print('\n', cluster_counts)

data_used['max_proba'] = data_used[['P_TRAIN_1', 'P_SM_2', 'P_CAR_3']].idxmax(axis=1).apply(extract_number)
cluster_counts2 = data_used.groupby(['cluster', 'max_proba']).size().unstack(fill_value=0)
print('\n', cluster_counts2)

cluster_counts3 = data_used.groupby(['cluster', 'simulated_choice']).size().unstack(fill_value=0)
print('\n', cluster_counts3)
# Out:
# Number of clusters : 3
#
#  cluster
# 0    4869
# 2    3784
# 1    2057
# Name: count, dtype: int64
#
#  CHOICE     1     2     3
# cluster
# 0        527  3452   890
# 1        680  1350    27
# 2        216  1411  2157
#
#  max_proba   1     2     3
# cluster
# 0           0  4869     0
# 1          67  1990     0
# 2           0  1573  2211
#
#  simulated_choice    1     2     3
# cluster
# 0                 673  3113  1083
# 1                 542  1505    10
# 2                 241  1591  1952
