# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from functions_NLM import estimate_nested_logit, simulate_choice
from functions_geom_DIB import geom_DIB_on_alternatives

# %%
# Load data
data = pd.read_csv('../data/airline.dat', sep='\t')
# display every column of the dataframe
pd.set_option('display.max_columns', None)
data
# Out:
#       SubjectId  OriginGMT  DestinationGMT  Direction  q02_TripPurpose  \
# 0             1        300             360          0                2
# 1             2        480             480          1                2
# 2             3        480             480          1                2
# 3             4        480             480          1                2
# 4             5        300             480          0                2
# ...         ...        ...             ...        ...              ...
# 3604       3609        480             300          2                3
# 3605       3610        480             300          2                2
# 3606       3611        300             360          0                1
# 3607       3612        300             480          0                2
# 3608       3613        360             360          1                2
#
#       q03_WhoPays  q11_DepartureOrArrivalIsImportant  q12_IdealDepTime  \
# 0               1                                  2                -1
# 1               1                                  2                -1
# 2               1                                  1                -1
# 3               3                                  1               630
# 4               1                                  0                -1
# ...           ...                                ...               ...
# 3604            1                                  2                -1
# 3605            1                                  2                -1
# 3606            1                                  2                -1
# 3607            1                                  2                -1
# 3608            1                                  2                -1
#
#       q13_IdealArrTime  q14_PartySize  q15_Age  q16_Income  Cont_Income  \
# 0                  480              2      3.5           9         92.5
# 1                  540              1      3.5          10        112.5
# 2                   -1              2      3.5           6         60.0
# 3                   -1              2      6.0          12        162.5
# 4                   -1              3      5.0          10        112.5
# ...                ...            ...      ...         ...          ...
# 3604               660              3      4.0           3         30.0
# 3605               480              1      3.0           5         50.0
# 3606               870              1      4.0           8         80.0
# 3607              1320              1      3.0          10        112.5
# 3608               705              3      4.0          99         -1.0
#
#       q17_Gender  q19_Occupation  q20_Education  AirlineFirstFlight_1  \
# 0              1               2              6                     5
# 1              1               1              6                     3
# 2              1               2              6                     5
# 3              2               2              6                     4
# 4              2               5              7                     7
# ...          ...             ...            ...                   ...
# 3604           2               5              2                     7
# 3605           1               2              7                     1
# 3606           1               7              7                    10
# 3607           1               1              7                     7
# 3608          99              99              4                     5
#
#       AirlineFirstFlight_2  AirlineFirstFlight_3  AirlineSecondFlight_1  \
# 0                        6                     3                     -1
# 1                        4                     5                     -1
# 2                        9                     2                     -1
# 3                        3                     7                     -1
# 4                        1                     4                     -1
# ...                    ...                   ...                    ...
# 3604                     3                     3                     -1
# 3605                     2                     7                     -1
# 3606                     1                     5                     -1
# 3607                     5                     4                     -1
# 3608                     7                    10                     -1
#
#       AirlineSecondFlight_2  AirlineSecondFlight_3  AirplaneFirstFlight_1  \
# 0                        -1                      2                      2
# 1                        -1                      1                      8
# 2                        -1                      6                      8
# 3                        -1                      6                      7
# 4                        -1                      3                      3
# ...                     ...                    ...                    ...
# 3604                     -1                      9                      5
# 3605                     -1                     10                      7
# 3606                     -1                      3                      4
# 3607                     -1                      6                      5
# 3608                     -1                      3                      1
#
#       AirplaneFirstFlight_2  AirplaneFirstFlight_3  AirplaneSecondFlight_1  \
# 0                         3                      7                      -1
# 1                         8                      2                      -1
# 2                         5                      5                      -1
# 3                         4                      6                      -1
# 4                         2                      2                      -1
# ...                     ...                    ...                     ...
# 3604                      7                      5                      -1
# 3605                      8                      8                      -1
# 3606                      4                      3                      -1
# 3607                      1                      6                      -1
# 3608                      2                      5                      -1
#
#       AirplaneSecondFlight_2  AirplaneSecondFlight_3  DepartureTimeHours_1  \
# 0                          8                       7                   7.0
# 1                          8                       1                   7.5
# 2                          6                       6                   7.5
# 3                          6                       8                  18.0
# 4                          3                       6                  10.5
# ...                      ...                     ...                   ...
# 3604                       2                       3                  12.0
# 3605                       6                       4                  12.0
# 3606                       3                       6                   9.0
# 3607                       5                       5                  10.0
# 3608                       4                       7                  10.5
#
#       DepartureTimeHours_2  DepartureTimeHours_3  DepartureTimeMins_1  \
# 0                      9.0                   9.0                  420
# 1                     15.0                  12.0                  450
# 2                      9.0                  12.0                  450
# 3                     18.0                  12.0                 1080
# 4                     15.0                  15.0                  630
# ...                    ...                   ...                  ...
# 3604                  11.0                   9.0                  720
# 3605                  10.0                   7.0                  720
# 3606                  16.5                  12.0                  540
# 3607                  11.0                  11.0                  600
# 3608                  10.5                  18.0                  630
#
#       DepartureTimeMins_2  DepartureTimeMins_3  ArrivalTimeHours_1  \
# 0                     540                  540             10.6167
# 1                     900                  720             10.0333
# 2                     540                  720             10.0333
# 3                    1080                  720             18.9667
# 4                     900                  900             11.8000
# ...                   ...                  ...                 ...
# 3604                  660                  540             19.2667
# 3605                  600                  420             20.3333
# 3606                  990                  720             10.3000
# 3607                  660                  660             13.1500
# 3608                  630                 1080             12.2500
#
#       ArrivalTimeHours_2  ArrivalTimeHours_3  ArrivalTimeMins_1  \
# 0                14.1167             13.6167                637
# 1                18.5333             16.5333                602
# 2                13.5333             17.0333                602
# 3                21.4667             13.9667               1138
# 4                18.3000             17.8000                708
# ...                  ...                 ...                ...
# 3604             19.2667             18.2667               1156
# 3605             19.8333             16.3333               1220
# 3606             18.8000             14.3000                618
# 3607             16.6500             15.6500                789
# 3608             14.2500             21.7500                735
#
#       ArrivalTimeMins_2  ArrivalTimeMins_3  FlyingTimeHours_1  \
# 0                   847                817           4.616670
# 1                  1112                992           2.533330
# 2                   812               1022           2.533330
# 3                  1288                838           0.966667
# 4                  1098               1068           4.300000
# ...                 ...                ...                ...
# 3604               1156               1096           4.266670
# 3605               1190                980           5.333330
# 3606               1128                858           2.300000
# 3607                999                939           6.150000
# 3608                855               1305           1.750000
#
#       FlyingTimeHours_2  FlyingTimeHours_3  TripTimeHours_1  TripTimeHours_2  \
# 0               5.11667            5.11667         4.616670          6.11667
# 1               3.03333            3.03333         2.533330          3.53333
# 2               3.03333            3.03333         2.533330          4.53333
# 3               1.46667            1.46667         0.966667          3.46667
# 4               4.80000            4.80000         4.300000          6.30000
# ...                 ...                ...              ...              ...
# 3604            4.76667            4.76667         4.266670          5.26667
# 3605            5.83333            5.83333         5.333330          6.83333
# 3606            2.80000            2.80000         2.300000          3.30000
# 3607            6.65000            6.65000         6.150000          8.65000
# 3608            2.25000            2.25000         1.750000          3.75000
#
#       TripTimeHours_3  Legroom_1  Legroom_2  Legroom_3  Fare_1  Fare_2  \
# 0             5.61667          2          3          4     835     835
# 1             4.53333          2          2          3     315     315
# 2             5.03333          3          1          4     195     160
# 3             1.96667          3          3          1     135     125
# 4             5.80000          3          2          3     270     300
# ...               ...        ...        ...        ...     ...     ...
# 3604          6.26667          3          3          4     650     480
# 3605          6.33333          2          3          4     760     690
# 3606          3.30000          2          1          4     290     290
# 3607          7.65000          3          4          3     480     360
# 3608          3.75000          1          1          3     360     375
#
#       Fare_3  BestAlternative_1  BestAlternative_2  BestAlternative_3  \
# 0        730                  0                  0                  1
# 1        350                  0                  1                  0
# 2        170                  0                  1                  0
# 3        140                  0                  0                  1
# 4        300                  1                  0                  0
# ...      ...                ...                ...                ...
# 3604     650                  0                  1                  0
# 3605     590                  0                  0                  1
# 3606     300                  0                  0                  1
# 3607     420                  1                  0                  0
# 3608     295                  0                  0                  1
#
#       TripPurpose
# 0               2
# 1               2
# 2               2
# 3               2
# 4               2
# ...           ...
# 3604            3
# 3605            2
# 3606            1
# 3607            2
# 3608            2
#
# [3609 rows x 56 columns]

# %%
# Find the column index with the maximum value (1)
choice_column_index = data[['BestAlternative_1', 'BestAlternative_2', 'BestAlternative_3']].idxmax(axis=1)

# Add 1 to the index to get the choice number
data['Choice'] = choice_column_index.str[-1].astype(int)

data_used = data[['SubjectId', 'TripTimeHours_1', 'TripTimeHours_2', 'TripTimeHours_3',
                   'Fare_1', 'Fare_2', 'Fare_3', 'Choice']]
data_used
# Out:
#       SubjectId  TripTimeHours_1  TripTimeHours_2  TripTimeHours_3  Fare_1  \
# 0             1         4.616670          6.11667          5.61667     835
# 1             2         2.533330          3.53333          4.53333     315
# 2             3         2.533330          4.53333          5.03333     195
# 3             4         0.966667          3.46667          1.96667     135
# 4             5         4.300000          6.30000          5.80000     270
# ...         ...              ...              ...              ...     ...
# 3604       3609         4.266670          5.26667          6.26667     650
# 3605       3610         5.333330          6.83333          6.33333     760
# 3606       3611         2.300000          3.30000          3.30000     290
# 3607       3612         6.150000          8.65000          7.65000     480
# 3608       3613         1.750000          3.75000          3.75000     360
#
#       Fare_2  Fare_3  Choice
# 0        835     730       3
# 1        315     350       2
# 2        160     170       2
# 3        125     140       3
# 4        300     300       1
# ...      ...     ...     ...
# 3604     480     650       2
# 3605     690     590       3
# 3606     290     300       3
# 3607     360     420       1
# 3608     375     295       3
#
# [3609 rows x 8 columns]

# %%
# beta_names = ["ASC_2", "ASC_3", "BETA_Time", "BETA_Cost", "lambda_21",
#                "lambda_13", "base_alpha_2_WITH_1"]

# DEFINE MODEL STRUCTURE AND LIKELIHOOD FUNCTION
def log_likelihood_optima_CNLM(beta, data):
    alpha_2_WITH_1 = np.exp(beta[6]) / (1 + np.exp(beta[6]))
    alpha_2_WITH_3 = 1 - alpha_2_WITH_1

    # define utility functions
    data['U_1'] = beta[2] * data['TripTimeHours_1'] + beta[3] * data['Fare_1']
    data['U_2'] = beta[0] + beta[2] * data['TripTimeHours_2'] + beta[3] * data['Fare_2']
    data['U_3'] = beta[1] + beta[2] * data['TripTimeHours_3'] + beta[3] * data['Fare_3']
 
    # combined utility terms inside nests
    data['U_12'] = (alpha_2_WITH_1 * np.exp(data['U_1'])) ** (1 / beta[4]) + \
                          (1 * np.exp(data['U_2'])) ** (1 / beta[4])
    data['U_23'] = (alpha_2_WITH_3 * np.exp(data['U_2'])) ** (1 / beta[5]) + \
                         (1 * np.exp(data['U_3'])) ** (1 / beta[5])

    # Nest probabilities
    data['P_nest_12'] = data['U_12'] ** beta[4] / \
                                (data['U_12'] ** beta[4] + data['U_23'] ** beta[5])
    data['P_nest_23'] = 1 - data['P_nest_12']

    # Within nest probabilities for any nests with > 1 alt
    data['P_2_in_12'] = (alpha_2_WITH_1 * np.exp(data['U_2'])) ** (1 / beta[4]) / \
                                    data['U_12'] 
    data['P_1_in_12'] = 1 - data['P_2_in_12']
    data['P_2_in_23'] = (alpha_2_WITH_3 * np.exp(data['U_2'])) ** (1 / beta[5]) / \
                                data['U_23']
    data['P_3_in_23'] = 1 - data['P_2_in_23']

    # Full probabilities
    data['P_1'] = data['P_nest_12'] * data['P_1_in_12']
    data['P_2'] = data['P_nest_12'] * data['P_2_in_12'] + data['P_nest_23'] * data['P_2_in_23']
    data['P_3'] = data['P_nest_23'] * data['P_3_in_23']

    # calculate probability for chosen alternative for each row in the data table
    data['P'] = ((data['Choice'] == 1) * data['P_1'] +
                 (data['Choice'] == 2) * data['P_2'] +
                 (data['Choice'] == 3) * data['P_3'])

    # take product across choices for the same person (likelihood)
    # then take the log for log-likelihood
    LL = data.groupby('SubjectId')['P'].prod().apply(np.log).sum()

    return -LL  # We minimize negative log-likelihood

# %%
# Define model parameters
beta = np.array([0, 0, 0, 0, 1, 1, 0])
beta_names = ["ASC_2", "ASC_3", "BETA_Time", "BETA_Cost", "lambda_12",
              "lambda_23", "base_alpha_2_WITH_1"]
# Estimate parameters
result, se, t_stat, p_value, aic, bic  = estimate_nested_logit(data_used, beta, beta_names, log_likelihood_optima_CNLM)
# Out:
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_1'] = beta[2] * data['TripTimeHours_1'] + beta[3] * data['Fare_1']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_2'] = beta[0] + beta[2] * data['TripTimeHours_2'] + beta[3] * data['Fare_2']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_3'] = beta[1] + beta[2] * data['TripTimeHours_3'] + beta[3] * data['Fare_3']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_12'] = (alpha_2_WITH_1 * np.exp(data['U_1'])) ** (1 / beta[4]) + \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_23'] = (alpha_2_WITH_3 * np.exp(data['U_2'])) ** (1 / beta[5]) + \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_nest_12'] = data['U_12'] ** beta[4] / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_nest_23'] = 1 - data['P_nest_12']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_2_in_12'] = (alpha_2_WITH_1 * np.exp(data['U_2'])) ** (1 / beta[4]) / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_1_in_12'] = 1 - data['P_2_in_12']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_2_in_23'] = (alpha_2_WITH_3 * np.exp(data['U_2'])) ** (1 / beta[5]) / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_3_in_23'] = 1 - data['P_2_in_23']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_1'] = data['P_nest_12'] * data['P_1_in_12']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_2'] = data['P_nest_12'] * data['P_2_in_12'] + data['P_nest_23'] * data['P_2_in_23']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_3'] = data['P_nest_23'] * data['P_3_in_23']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P'] = ((data['Choice'] == 1) * data['P_1'] +
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_1'] = beta[2] * data['TripTimeHours_1'] + beta[3] * data['Fare_1']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_2'] = beta[0] + beta[2] * data['TripTimeHours_2'] + beta[3] * data['Fare_2']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_3'] = beta[1] + beta[2] * data['TripTimeHours_3'] + beta[3] * data['Fare_3']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_12'] = (alpha_2_WITH_1 * np.exp(data['U_1'])) ** (1 / beta[4]) + \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_23'] = (alpha_2_WITH_3 * np.exp(data['U_2'])) ** (1 / beta[5]) + \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_nest_12'] = data['U_12'] ** beta[4] / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_nest_23'] = 1 - data['P_nest_12']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_2_in_12'] = (alpha_2_WITH_1 * np.exp(data['U_2'])) ** (1 / beta[4]) / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_1_in_12'] = 1 - data['P_2_in_12']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_2_in_23'] = (alpha_2_WITH_3 * np.exp(data['U_2'])) ** (1 / beta[5]) / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_3_in_23'] = 1 - data['P_2_in_23']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_1'] = data['P_nest_12'] * data['P_1_in_12']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_2'] = data['P_nest_12'] * data['P_2_in_12'] + data['P_nest_23'] * data['P_2_in_23']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_3'] = data['P_nest_23'] * data['P_3_in_23']
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:590: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_1'] = beta[2] * data['TripTimeHours_1'] + beta[3] * data['Fare_1']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_2'] = beta[0] + beta[2] * data['TripTimeHours_2'] + beta[3] * data['Fare_2']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_3'] = beta[1] + beta[2] * data['TripTimeHours_3'] + beta[3] * data['Fare_3']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_12'] = (alpha_2_WITH_1 * np.exp(data['U_1'])) ** (1 / beta[4]) + \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_23'] = (alpha_2_WITH_3 * np.exp(data['U_2'])) ** (1 / beta[5]) + \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_nest_12'] = data['U_12'] ** beta[4] / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_nest_23'] = 1 - data['P_nest_12']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_2_in_12'] = (alpha_2_WITH_1 * np.exp(data['U_2'])) ** (1 / beta[4]) / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_1_in_12'] = 1 - data['P_2_in_12']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_2_in_23'] = (alpha_2_WITH_3 * np.exp(data['U_2'])) ** (1 / beta[5]) / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_3_in_23'] = 1 - data['P_2_in_23']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_1'] = data['P_nest_12'] * data['P_1_in_12']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_2'] = data['P_nest_12'] * data['P_2_in_12'] + data['P_nest_23'] * data['P_2_in_23']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_3'] = data['P_nest_23'] * data['P_3_in_23']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P'] = ((data['Choice'] == 1) * data['P_1'] +
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_1'] = beta[2] * data['TripTimeHours_1'] + beta[3] * data['Fare_1']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_2'] = beta[0] + beta[2] * data['TripTimeHours_2'] + beta[3] * data['Fare_2']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_3'] = beta[1] + beta[2] * data['TripTimeHours_3'] + beta[3] * data['Fare_3']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_12'] = (alpha_2_WITH_1 * np.exp(data['U_1'])) ** (1 / beta[4]) + \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_23'] = (alpha_2_WITH_3 * np.exp(data['U_2'])) ** (1 / beta[5]) + \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_nest_12'] = data['U_12'] ** beta[4] / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_nest_23'] = 1 - data['P_nest_12']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_2_in_12'] = (alpha_2_WITH_1 * np.exp(data['U_2'])) ** (1 / beta[4]) / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_1_in_12'] = 1 - data['P_2_in_12']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_2_in_23'] = (alpha_2_WITH_3 * np.exp(data['U_2'])) ** (1 / beta[5]) / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_3_in_23'] = 1 - data['P_2_in_23']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_1'] = data['P_nest_12'] * data['P_1_in_12']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_2'] = data['P_nest_12'] * data['P_2_in_12'] + data['P_nest_23'] * data['P_2_in_23']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_3'] = data['P_nest_23'] * data['P_3_in_23']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P'] = ((data['Choice'] == 1) * data['P_1'] +
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:590: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_1'] = beta[2] * data['TripTimeHours_1'] + beta[3] * data['Fare_1']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_2'] = beta[0] + beta[2] * data['TripTimeHours_2'] + beta[3] * data['Fare_2']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_3'] = beta[1] + beta[2] * data['TripTimeHours_3'] + beta[3] * data['Fare_3']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_12'] = (alpha_2_WITH_1 * np.exp(data['U_1'])) ** (1 / beta[4]) + \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_23'] = (alpha_2_WITH_3 * np.exp(data['U_2'])) ** (1 / beta[5]) + \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_nest_12'] = data['U_12'] ** beta[4] / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_nest_23'] = 1 - data['P_nest_12']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_2_in_12'] = (alpha_2_WITH_1 * np.exp(data['U_2'])) ** (1 / beta[4]) / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_1_in_12'] = 1 - data['P_2_in_12']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_2_in_23'] = (alpha_2_WITH_3 * np.exp(data['U_2'])) ** (1 / beta[5]) / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_3_in_23'] = 1 - data['P_2_in_23']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_1'] = data['P_nest_12'] * data['P_1_in_12']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_2'] = data['P_nest_12'] * data['P_2_in_12'] + data['P_nest_23'] * data['P_2_in_23']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_3'] = data['P_nest_23'] * data['P_3_in_23']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P'] = ((data['Choice'] == 1) * data['P_1'] +
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_1'] = beta[2] * data['TripTimeHours_1'] + beta[3] * data['Fare_1']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_2'] = beta[0] + beta[2] * data['TripTimeHours_2'] + beta[3] * data['Fare_2']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_3'] = beta[1] + beta[2] * data['TripTimeHours_3'] + beta[3] * data['Fare_3']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_12'] = (alpha_2_WITH_1 * np.exp(data['U_1'])) ** (1 / beta[4]) + \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_23'] = (alpha_2_WITH_3 * np.exp(data['U_2'])) ** (1 / beta[5]) + \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_nest_12'] = data['U_12'] ** beta[4] / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_nest_23'] = 1 - data['P_nest_12']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_2_in_12'] = (alpha_2_WITH_1 * np.exp(data['U_2'])) ** (1 / beta[4]) / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_1_in_12'] = 1 - data['P_2_in_12']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_2_in_23'] = (alpha_2_WITH_3 * np.exp(data['U_2'])) ** (1 / beta[5]) / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_3_in_23'] = 1 - data['P_2_in_23']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_1'] = data['P_nest_12'] * data['P_1_in_12']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_2'] = data['P_nest_12'] * data['P_2_in_12'] + data['P_nest_23'] * data['P_2_in_23']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_3'] = data['P_nest_23'] * data['P_3_in_23']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P'] = ((data['Choice'] == 1) * data['P_1'] +
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/scipy/optimize/_numdiff.py:590: RuntimeWarning: invalid value encountered in subtract
#   df = fun(x) - f0
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_1'] = beta[2] * data['TripTimeHours_1'] + beta[3] * data['Fare_1']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_2'] = beta[0] + beta[2] * data['TripTimeHours_2'] + beta[3] * data['Fare_2']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_3'] = beta[1] + beta[2] * data['TripTimeHours_3'] + beta[3] * data['Fare_3']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_12'] = (alpha_2_WITH_1 * np.exp(data['U_1'])) ** (1 / beta[4]) + \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['U_23'] = (alpha_2_WITH_3 * np.exp(data['U_2'])) ** (1 / beta[5]) + \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_nest_12'] = data['U_12'] ** beta[4] / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_nest_23'] = 1 - data['P_nest_12']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_2_in_12'] = (alpha_2_WITH_1 * np.exp(data['U_2'])) ** (1 / beta[4]) / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_1_in_12'] = 1 - data['P_2_in_12']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_2_in_23'] = (alpha_2_WITH_3 * np.exp(data['U_2'])) ** (1 / beta[5]) / \
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_3_in_23'] = 1 - data['P_2_in_23']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_1'] = data['P_nest_12'] * data['P_1_in_12']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_2'] = data['P_nest_12'] * data['P_2_in_12'] + data['P_nest_23'] * data['P_2_in_23']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P_3'] = data['P_nest_23'] * data['P_3_in_23']
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/3407104992.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['P'] = ((data['Choice'] == 1) * data['P_1'] +
# Optimization Results:
#              Parameter  Estimate  Robust Asymptotic SE  t-statistic   p-value
# 0                ASC_2 -2.971450              0.663946    -4.475443  0.000008
# 1                ASC_3 -0.821299              0.828559    -0.991238  0.321636
# 2            BETA_Time -1.516829              0.457159    -3.317946  0.000916
# 3            BETA_Cost -0.033136              0.001006   -32.929680  0.000000
# 4            lambda_12  1.882627              0.113223    16.627642  0.000000
# 5            lambda_23  0.000470              0.204406     0.002297  0.998167
# 6  base_alpha_2_WITH_1  2.154454              1.060836     2.030903  0.042338
# AIC: 14.0
# BIC: 57.33830203249953
# Log-likelihood: 0.0

# %%
df_input = data[['TripTimeHours_1', 'TripTimeHours_2', 'TripTimeHours_3',
                   'Fare_1', 'Fare_2', 'Fare_3']]
# Calculate frequencies and probabilities
vector_counts = df_input.value_counts().reset_index(name='Frequency')
vector_counts['Probability'] = vector_counts['Frequency'] / len(df_input)

# Creating a tuple of attributes to facilitate mapping
vector_counts['tuple'] = vector_counts[['TripTimeHours_1', 'TripTimeHours_2', 'TripTimeHours_3',
                                        'Fare_1', 'Fare_2', 'Fare_3']].apply(tuple, axis=1)
probability_map = vector_counts.set_index('tuple')['Probability'].to_dict()

# Assign the probability to each row based on its tuple of attributes
df_input['Probability'] = df_input.apply(lambda row: probability_map[tuple(row)], axis=1)
# Out:
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/1916923433.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_input['Probability'] = df_input.apply(lambda row: probability_map[tuple(row)], axis=1)

# %%
# Computation of p(x,y)
p_x = df_input['Probability'].values

p_y_given_x = data_used[['P_1', 'P_2', 'P_3']].values
p_xy = p_x[:, np.newaxis] * p_y_given_x

# Normalize p_xy 
p_xy /= p_xy.sum()

# Define epsilon value
epsilon = 1e-20

# Add epsilon to elements equal to 0
p_xy[p_xy == 0] += epsilon

# %%
def simulate_choice_optima(row):
    """
    Function to simulate a choice based on cumulative probabilities.

    Parameters:
    - row: pandas Series or DataFrame row containing probabilities for each choice

    Returns:
    - The simulated choice (an integer between 1 and the number of choices)
    """
    # Generate a random number between 0 and 1
    random_number = np.random.rand()
    
    # Calculate cumulative probabilities
    probabilities = row[['P_1', 'P_2', 'P_3']]
    cumulative_probs = probabilities.cumsum()
    
    # Determine simulated choice based on random number
    for i, cumulative_prob in enumerate(cumulative_probs):
        if random_number <= cumulative_prob:
            return i+1

# %%
np.random.seed(123)
data_used['simulated_choice'] = data_used.apply(simulate_choice_optima, axis=1)
data_used
# Out:
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_3749/2856924636.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_used['simulated_choice'] = data_used.apply(simulate_choice_optima, axis=1)
#       SubjectId  TripTimeHours_1  TripTimeHours_2  TripTimeHours_3  Fare_1  \
# 0             1         4.616670          6.11667          5.61667     835
# 1             2         2.533330          3.53333          4.53333     315
# 2             3         2.533330          4.53333          5.03333     195
# 3             4         0.966667          3.46667          1.96667     135
# 4             5         4.300000          6.30000          5.80000     270
# ...         ...              ...              ...              ...     ...
# 3604       3609         4.266670          5.26667          6.26667     650
# 3605       3610         5.333330          6.83333          6.33333     760
# 3606       3611         2.300000          3.30000          3.30000     290
# 3607       3612         6.150000          8.65000          7.65000     480
# 3608       3613         1.750000          3.75000          3.75000     360
#
#       Fare_2  Fare_3  Choice        U_1        U_2        U_3          U_12  \
# 0        835     730       3 -34.671136 -39.917830 -33.530000  1.009348e-08
# 1        315     350       2 -14.280422 -18.768702 -19.295134  5.258858e-04
# 2        160     170       2 -10.304120 -15.149474 -14.089095  4.279920e-03
# 3        125     140       3  -5.939609 -12.371778  -8.443421  4.162575e-02
# 4        300     300       1 -15.469045 -22.468229 -19.559664  2.613643e-04
# ...      ...     ...     ...        ...        ...        ...           ...
# 3604     480     650       2 -28.010114 -26.865298 -31.865071  9.606615e-07
# 3605     690     590       3 -33.272998 -36.200182 -29.978031  2.436917e-08
# 3606     290     300       3 -13.098104 -17.586384 -15.767591  9.854507e-04
# 3607     360     420       1 -25.233708 -28.020929 -26.342100  1.767975e-06
# 3608     375     295       3 -14.583358 -21.085504 -16.284485  4.215436e-04
#
#       U_23  P_nest_12  P_nest_23  P_2_in_12  P_1_in_12  P_2_in_23  P_3_in_23  \
# 0      0.0        1.0        0.0   0.057835   0.942165        NaN        NaN
# 1      0.0        1.0        0.0   0.083972   0.916028        NaN        NaN
# 2      0.0        1.0        0.0   0.070549   0.929451        NaN        NaN
# 3      0.0        1.0        0.0   0.031720   0.968280        NaN        NaN
# 4      0.0        1.0        0.0   0.023678   0.976322        NaN        NaN
# ...    ...        ...        ...        ...        ...        ...        ...
# 3604   0.0        1.0        0.0   0.623286   0.376714        NaN        NaN
# 3605   0.0        1.0        0.0   0.172582   0.827418        NaN        NaN
# 3606   0.0        1.0        0.0   0.083972   0.916028        NaN        NaN
# 3607   0.0        1.0        0.0   0.183314   0.816686        NaN        NaN
# 3608   0.0        1.0        0.0   0.030601   0.969399        NaN        NaN
#
#            P_1  P_2  P_3   P  simulated_choice
# 0     0.942165  NaN  NaN NaN               1.0
# 1     0.916028  NaN  NaN NaN               1.0
# 2     0.929451  NaN  NaN NaN               1.0
# 3     0.968280  NaN  NaN NaN               1.0
# 4     0.976322  NaN  NaN NaN               1.0
# ...        ...  ...  ...  ..               ...
# 3604  0.376714  NaN  NaN NaN               NaN
# 3605  0.827418  NaN  NaN NaN               1.0
# 3606  0.916028  NaN  NaN NaN               1.0
# 3607  0.816686  NaN  NaN NaN               1.0
# 3608  0.969399  NaN  NaN NaN               1.0
#
# [3609 rows x 24 columns]

# %%
betas = np.linspace(0, 50, 51)
# Initialize an empty list to store the number of clusters
num_clusters_list = []

# Iterate over each beta value
for beta in betas:
    # Run iterative_algorithm to obtain q_t_given_x
    q_t_given_x, _, _ = geom_DIB_on_alternatives(p_xy, max_iter=5000, beta=beta, threshold=1e-4)
    
    # Calculate the number of clusters
    column_sum = np.sum(q_t_given_x, axis=0)
    num_clusters = np.count_nonzero(column_sum)
    
    # Append the number of clusters to the list
    num_clusters_list.append(num_clusters)

# Plot the number of clusters against beta values
plt.plot(betas, num_clusters_list)
plt.xlabel('Beta')
plt.ylabel('Number of Clusters')
plt.title('Number of Clusters vs. Beta')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[10], line 8
#       5 # Iterate over each beta value
#       6 for beta in betas:
#       7     # Run iterative_algorithm to obtain q_t_given_x
# ----> 8     q_t_given_x, _, _ = geom_DIB_on_alternatives(p_xy, max_iter=5000, beta=beta, threshold=1e-4)
#      10     # Calculate the number of clusters
#      11     column_sum = np.sum(q_t_given_x, axis=0)
#
# File ~/Documents/GitHub/Semester_project_information_cluser/notebook-airline/functions_geom_DIB.py:343, in geom_DIB_on_alternatives(p_xy, max_iter, beta, threshold)
#     338 #q_t_given_x = np.zeros((num_data_points, num_clusters))
#     339
#     340 # Iterative algorithm
#     341 # Initalize the objective functions for old and new state
#     342 objective_old = 0
# --> 343 H_T = entropy(q_t)
#     344 I_TY = mutual_information(q_t.reshape(-1, 1) * q_y_given_t)
#     345 objective_new = H_T - beta * I_TY
#
# File ~/Documents/GitHub/Semester_project_information_cluser/notebook-airline/functions_IB.py:44, in entropy(probabilities)
#      41 probabilities = np.array(probabilities)
#      43 # Ensure probabilities sum up to 1
# ---> 44 assert np.isclose(np.sum(probabilities), 1.0), "Probabilities must sum up to 1"
#      46 # Remove zeros to avoid issues with log calculation
#      47 probabilities = probabilities[probabilities > 0]
#
# AssertionError: Probabilities must sum up to 1

# %%
q_t_given_x, q_t, q_y_given_t = geom_DIB_on_alternatives(p_xy, beta=50, max_iter=5000, threshold=1e-5)
# Out:
# Iteration: 1 out of 5000
# Objective function value: 1.0860474103737379
# H(T) =  1.0985982748094387
# I(T;Y) =  0.0002510172887140172
# Iteration: 2 out of 5000
# Objective function value: -2.3167012731591496
# H(T) =  0.8910218399738825
# I(T;Y) =  0.06415446226266064
# Iteration: 3 out of 5000
# Objective function value: -2.631379895817838
# H(T) =  1.0031492314216006
# I(T;Y) =  0.07269058254478877
# Iteration: 4 out of 5000
# Objective function value: -2.9544612953996143
# H(T) =  1.067976907685951
# I(T;Y) =  0.08044876406171131
# Iteration: 5 out of 5000
# Objective function value: -3.2364531506465903
# H(T) =  1.0837983424787476
# I(T;Y) =  0.08640502986250675
# Iteration: 6 out of 5000
# Objective function value: -3.355437389539399
# H(T) =  1.0814163050285108
# I(T;Y) =  0.08873707389135821
# Iteration: 7 out of 5000
# Objective function value: -3.4873475736315447
# H(T) =  1.063872713802799
# I(T;Y) =  0.09102440574868687
# Iteration: 8 out of 5000
# Objective function value: -3.70967103722953
# H(T) =  1.0217891084959112
# I(T;Y) =  0.09462920291450883
# Iteration: 9 out of 5000
# Objective function value: -3.8435778180278035
# H(T) =  0.9854403695482139
# I(T;Y) =  0.09658036375152035
# Iteration: 10 out of 5000
# Objective function value: -3.91100034550527
# H(T) =  0.961154601492239
# I(T;Y) =  0.09744309893995018
# Iteration: 11 out of 5000
# Objective function value: -3.9359030384226807
# H(T) =  0.9523674527107804
# I(T;Y) =  0.09776540982266924
# Iteration: 12 out of 5000
# Objective function value: -3.9442368273665185
# H(T) =  0.9488847622080048
# I(T;Y) =  0.09786243179149046
# Iteration: 13 out of 5000
# Objective function value: -3.9483628363287027
# H(T) =  0.9503746155130368
# I(T;Y) =  0.09797474903683479
# Iteration: 14 out of 5000
# Objective function value: -3.9490932451133087
# H(T) =  0.9508507064833658
# I(T;Y) =  0.0979988790319335
# Iteration: 15 out of 5000
# Objective function value: -3.949146399294741
# H(T) =  0.9498356832197399
# I(T;Y) =  0.0979796416502896
# Iteration: 16 out of 5000
# Objective function value: -3.949180012731788
# H(T) =  0.9491656468674685
# I(T;Y) =  0.09796691319198514
# Iteration: 17 out of 5000
# Objective function value: -3.9492275322526575
# H(T) =  0.9482667633584798
# I(T;Y) =  0.09794988591222276
# Iteration: 18 out of 5000
# Objective function value: -3.9492414605073103
# H(T) =  0.9478149594845198
# I(T;Y) =  0.0979411283998366

# %%
import re

# Define a function to extract the number from the column name
def extract_number(column_name):
    match = re.search(r'\d+', column_name)  # Search for one or more digits in the column name
    if match:
        return int(match.group())  # Return the first occurrence of digits as an integer
    else:
        return None  # Return None if no digits are found

# %%
# Calculate the number of clusters
column_sum = np.sum(q_t_given_x, axis=0)
num_clusters = np.count_nonzero(column_sum)
print('Number of clusters :', num_clusters)

# Count the number of observations in each cluster
data_used['cluster'] = np.argmax(q_t_given_x, axis=1)
print('\n', data_used['cluster'].value_counts())

# number of each alternative 1, 2, 3, 4, 5 in each cluster 
cluster_counts = data_used.groupby(['cluster', 'Choice']).size().unstack(fill_value=0)
print('\n', cluster_counts)

data_used['max_proba'] = data_used[['P_1', 'P_2', 'P_3']].idxmax(axis=1).apply(extract_number)
cluster_counts2 = data_used.groupby(['cluster', 'max_proba']).size().unstack(fill_value=0)
print('\n', cluster_counts2)

cluster_counts3 = data_used.groupby(['cluster', 'simulated_choice']).size().unstack(fill_value=0)
print('\n', cluster_counts3)
# Out:
# Number of clusters : 3
#
#  cluster
# 1    2140
# 0     910
# 2     559
# Name: count, dtype: int64
#
#  Choice      1    2    3
# cluster
# 0         458  381   71
# 1        1807  151  182
# 2         239   57  263
#
#  max_proba     1    2    3
# cluster
# 0           673  237    0
# 1          2140    0    0
# 2           358    3  198
#
#  simulated_choice     1    2    3
# cluster
# 0                  494  343   73
# 1                 1757  175  208
# 2                  255   65  239
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_7202/687862934.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_used['cluster'] = np.argmax(q_t_given_x, axis=1)
# /var/folders/gk/16047hxn3hdgt8s5qmq_gnqh0000gp/T/ipykernel_7202/687862934.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_used['max_proba'] = data_used[['P_1', 'P_2', 'P_3']].idxmax(axis=1).apply(extract_number)
